# %% [markdown]
# I am trying to get the probabilities of the prediction in this notebook

# %%
language = 'ja'
import name_transliteration.filtering as filter
import name_transliteration.cleansing as cleanse
import name_transliteration.model_trainer_and_tester as model_trainer_and_tester

# %%
# filter testing and training data

my_filter = filter.Filter(language)
my_filter.filterData("./data/")
# Out:
# ./data/stream-2021-03-07T03:05:07.831679.gz
# ./data/stream-2021-01-13T01:21:29.804195.gz
# ./data/stream-2021-01-13T04:07:46.253913.gz
# ./data/stream-2021-01-12T23:08:30.828340.gz
# ./data/stream-2021-01-13T03:38:20.383129.gz
# ./data/stream-2021-03-07T06:30:03.830030.gz
# ./data/stream-2021-01-13T04:37:35.200990.gz
# ./data/stream-2021-03-07T03:34:53.811604.gz
# ./data/stream-2021-04-17T07:23:41.809159.gz
# ./data/stream-2021-01-12T22:39:33.810384.gz
# ./data/stream-2021-03-06T03:25:42.946878.gz
# ./data/stream-2021-01-12T22:09:26.798946.gz
# ./data/stream-2021-03-07T04:06:04.938654.gz
# ./data/stream-2021-03-07T01:39:45.126113.gz
# ./data/stream-2021-03-07T08:30:55.833881.gz
# ./data/stream-2021-03-07T02:36:22.842559.gz
# ./data/stream-2021-03-06T01:33:50.975776.gz
# ./data/stream-2021-03-06T01:59:57.825571.gz
# ./data/stream-2021-03-07T07:50:03.791977.gz
# ./data/stream-2021-04-17T04:49:34.818794.gz
# ./data/stream-2021-03-06T00:38:21.058969.gz
# ./data/stream-2021-03-07T01:29:37.938029.gz
# ./data/stream-2021-01-13T00:02:22.807571.gz
# ./data/stream-2021-03-06T23:16:19.931951.gz
# ./data/stream-2021-01-13T02:14:13.914215.gz
# ./data/stream-2021-03-07T05:50:51.797120.gz
# ./data/stream-2021-03-06T02:27:32.944437.gz
# ./data/stream-2021-04-17T06:45:57.765273.gz
# ./data/stream-2021-03-06T22:46:55.051822.gz
# ./data/stream-2021-04-17T05:28:35.936895.gz
# ./data/stream-2021-03-06T03:56:50.840797.gz
# ./data/stream-2021-03-06T23:44:28.885165.gz
# ./data/stream-2021-03-07T00:38:41.940824.gz
# ./data/stream-2021-04-17T03:33:36.470062.gz
# ./data/stream-2021-03-07T01:54:03.127902.gz
# ./data/stream-2021-03-07T01:04:07.119423.gz
# ./data/stream-2021-01-13T03:09:29.015229.gz
# ./data/stream-2021-03-07T06:39:59.560376.gz
# ./data/stream-2021-04-17T06:07:42.842366.gz
# ./data/stream-2021-01-13T00:55:27.831486.gz
# ./data/stream-2021-03-06T04:30:10.792693.gz
# ./data/stream-2021-01-13T05:09:14.938774.gz
# ./data/stream-2021-03-06T02:55:50.791026.gz
# ./data/stream-2021-04-17T03:36:31.821630.gz
# ./data/stream-2021-03-07T04:38:41.798997.gz
# ./data/stream-2021-01-12T23:35:55.813786.gz
# ./data/stream-2021-01-13T00:28:46.798948.gz
# ./data/stream-2021-03-07T00:12:11.870181.gz
# ./data/stream-2021-04-17T04:12:10.798493.gz
# ./data/stream-2021-03-07T05:13:24.789931.gz
# ./data/stream-2021-01-13T01:47:06.536491.gz
# ./data/stream-2021-01-13T02:42:07.071964.gz

# %%
# instantiate the cleanser
my_cleanser = cleanse.Cleanser()
# the split data is uncleansed btw
my_cleanser.splitTrainTest(my_filter.getDataFrame())
# this does the cleansing of the test datasets
my_cleanser.createTestDataSets()
# this does the cleansing of the training dataset
my_cleanser.createTrainDataSet(edit_threshold = 0.3)

# %%
my_cleanser.saveTestAndTrain()
# Out:
# Saved cleansed names as:
# train_30_edit_distance_language_cleansed.txt 59355 number of rows.
# test1_cleansed.txt 159 number of rows.
# test2_cleansed.txt 218 number of rows.
# test3_cleansed.txt 499 number of rows.

# %%
trainer_and_tester = model_trainer_and_tester.ModelTrainerAndTester(
    language=language, 
    epochs=20
)
trainer_and_tester.runWholeTrainProcess('train_0_edit_distance_language_cleansed.txt')
# Out:
# Number of unique input tokens: 27
# Number of unique output tokens: 1516
# Max sequence length for inputs: 17
# Max sequence length for outputs: 13
# Epoch 1/20
# 431/431 [==============================] - 42s 90ms/step - loss: 1.8771 - accuracy: 0.6829 - val_loss: 1.3603 - val_accuracy: 0.7444
# Epoch 2/20
# 431/431 [==============================] - 38s 87ms/step - loss: 1.3299 - accuracy: 0.7459 - val_loss: 1.1950 - val_accuracy: 0.7647
# Epoch 3/20
# 431/431 [==============================] - 38s 87ms/step - loss: 1.1543 - accuracy: 0.7710 - val_loss: 1.0698 - val_accuracy: 0.7838
# Epoch 4/20
# 431/431 [==============================] - 37s 86ms/step - loss: 0.9906 - accuracy: 0.7958 - val_loss: 0.8769 - val_accuracy: 0.8188
# Epoch 5/20
# 431/431 [==============================] - 37s 87ms/step - loss: 0.8200 - accuracy: 0.8294 - val_loss: 0.7834 - val_accuracy: 0.8390
# Epoch 6/20
# 431/431 [==============================] - 37s 85ms/step - loss: 0.6844 - accuracy: 0.8589 - val_loss: 0.6650 - val_accuracy: 0.8655
# Epoch 7/20
# 431/431 [==============================] - 37s 85ms/step - loss: 0.5976 - accuracy: 0.8786 - val_loss: 0.6124 - val_accuracy: 0.8794
# Epoch 8/20
# 431/431 [==============================] - 37s 85ms/step - loss: 0.5236 - accuracy: 0.8954 - val_loss: 0.5488 - val_accuracy: 0.8950
# Epoch 9/20
# 431/431 [==============================] - 37s 85ms/step - loss: 0.4780 - accuracy: 0.9063 - val_loss: 0.5568 - val_accuracy: 0.8947
# Epoch 10/20
# 431/431 [==============================] - 37s 86ms/step - loss: 0.4286 - accuracy: 0.9173 - val_loss: 0.5057 - val_accuracy: 0.9042
# Epoch 11/20
# 431/431 [==============================] - 37s 86ms/step - loss: 0.3978 - accuracy: 0.9236 - val_loss: 0.4878 - val_accuracy: 0.9090
# Epoch 12/20
# 431/431 [==============================] - 37s 86ms/step - loss: 0.3710 - accuracy: 0.9293 - val_loss: 0.4700 - val_accuracy: 0.9131
# Epoch 13/20
# 431/431 [==============================] - 37s 86ms/step - loss: 0.3485 - accuracy: 0.9348 - val_loss: 0.4552 - val_accuracy: 0.9175
# Epoch 14/20
# 431/431 [==============================] - 36s 84ms/step - loss: 0.3222 - accuracy: 0.9399 - val_loss: 0.4470 - val_accuracy: 0.9180
# Epoch 15/20
# 431/431 [==============================] - 37s 85ms/step - loss: 0.2960 - accuracy: 0.9448 - val_loss: 0.4451 - val_accuracy: 0.9207
# Epoch 16/20
# 431/431 [==============================] - 37s 87ms/step - loss: 0.2825 - accuracy: 0.9469 - val_loss: 0.4394 - val_accuracy: 0.9204
# Epoch 17/20
# 431/431 [==============================] - 36s 85ms/step - loss: 0.2683 - accuracy: 0.9508 - val_loss: 0.4450 - val_accuracy: 0.9197
# Epoch 18/20
# 431/431 [==============================] - 37s 85ms/step - loss: 0.2490 - accuracy: 0.9544 - val_loss: 0.4335 - val_accuracy: 0.9212
# Epoch 19/20
# 431/431 [==============================] - 37s 87ms/step - loss: 0.2413 - accuracy: 0.9565 - val_loss: 0.4321 - val_accuracy: 0.9225
# Epoch 20/20
# 431/431 [==============================] - 37s 86ms/step - loss: 0.2309 - accuracy: 0.9588 - val_loss: 0.4314 - val_accuracy: 0.9216
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ja_model_20/assets

# %%
trainer_and_tester.evaluateOnTestData("ja_model_20")
# Out:
# evaluating on test set with 0 edit threshold...
# 5/5 [==============================] - 1s 28ms/step - loss: 0.4673 - accuracy: 0.9110
# test loss, test acc: [0.4672572910785675, 0.910982072353363]
# evaluating on test set with 0.1 edit threshold...
# 7/7 [==============================] - 0s 28ms/step - loss: 0.7296 - accuracy: 0.8758
# test loss, test acc: [0.7295599579811096, 0.8757939338684082]
# evaluating on test set with 0.25 edit threshold...
# 16/16 [==============================] - 0s 28ms/step - loss: 1.1537 - accuracy: 0.8283
# test loss, test acc: [1.1537402868270874, 0.8282719254493713]

# %%
trainer_and_tester.predict("yuzukichi")
# Out:
# ('ゆずきち\n', 0.99999344)

# %%
trainer_and_tester.saveTrainingStats()

# %%
# create a second filter to get the japanese data again
# filter testing and training data

my_filter2 = filter.Filter(language)
my_filter2.filterData("./data/",5)
# Out:
# ./data/stream-2021-03-07T03:05:07.831679.gz
# ./data/stream-2021-01-13T01:21:29.804195.gz
# ./data/stream-2021-01-13T04:07:46.253913.gz
# ./data/stream-2021-01-12T23:08:30.828340.gz
# ./data/stream-2021-01-13T03:38:20.383129.gz

# %%
import re

def transformUserName(line):
    # strip numbers
    text = re.sub(r'\d+', '', line)
    # underscores to spaces
    text = re.sub(r'_', ' ', text)
    # add a space between lower case and upper case words
    text = re.sub(r"(\w)([A-Z])", r"\1 \2", text)
    return text.lower().strip()

# %%
probability_list = []

for index, row in my_filter2.getDataFrame().iterrows():
    clean_username = transformUserName(row["username"])
    if len(clean_username) < 17:
        _, prob = trainer_and_tester.predict(clean_username)
        probability_list.append(prob)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-bf38b5974023> in <module>
#       4     clean_username = transformUserName(row["username"])
#       5     if len(clean_username) < 17:
# ----> 6         _, prob = trainer_and_tester.predict(clean_username)
#       7         probability_list.append(prob)
#
# ~/Documents/GitHub/name_transliteration/name_transliteration/model_trainer_and_tester.py in predict(self, name)
#     280             one_hot_vector[0, t, self.input_token_index[char]] = 1.0
#     281         one_hot_vector[0, t + 1 :, self.input_token_index[" "]] = 1.0
# --> 282         return self.decode_sequence(one_hot_vector[0:1], name)
#     283
#     284
#
# ~/Documents/GitHub/name_transliteration/name_transliteration/model_trainer_and_tester.py in decode_sequence(self, input_seq, name_as_string)
#     236
#     237             # see if output_tokens sum up to 1 or not
# --> 238             output_tokens, h, c = self.decoder_model.predict([target_seq] + states_value)
#     239             # print("output_tokens: " + str(output_tokens))
#     240             # print("h: " + str(h))
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1596                         '. Consider setting it to AutoShardPolicy.DATA.')
#    1597
# -> 1598       data_handler = data_adapter.DataHandler(
#    1599           x=x,
#    1600           batch_size=batch_size,
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1098
#    1099     adapter_cls = select_data_adapter(x, y)
# -> 1100     self._adapter = adapter_cls(
#    1101         x,
#    1102         y,
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     353     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     354
# --> 355     dataset = self.slice_inputs(indices_dataset, inputs)
#     356
#     357     if shuffle == "batch":
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     385       return nest.map_structure(lambda d: array_ops.gather(d, i, axis=0), data)
#     386
# --> 387     dataset = dataset.map(
#     388         grab_batch, num_parallel_calls=dataset_ops.AUTOTUNE)
#     389
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic)
#    1805       return MapDataset(self, map_func, preserve_cardinality=True)
#    1806     else:
# -> 1807       return ParallelMapDataset(
#    1808           self,
#    1809           map_func,
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    4240     self._input_dataset = input_dataset
#    4241     self._use_inter_op_parallelism = use_inter_op_parallelism
# -> 4242     self._map_func = StructuredFunctionWrapper(
#    4243         map_func,
#    4244         self._transformation_name(),
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    3523       with tracking.resource_tracker_scope(resource_tracker):
#    3524         # TODO(b/141462134): Switch to using garbage collection.
# -> 3525         self._function = wrapper_fn.get_concrete_function()
#    3526         if add_to_graph:
#    3527           self._function.add_to_graph(ops.get_default_graph())
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3049       **kwargs: inputs to specialize on.
#    3050     """
# -> 3051     graph_function = self._get_concrete_function_garbage_collected(
#    3052         *args, **kwargs)
#    3053     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3017       args, kwargs = None, None
#    3018     with self._lock:
# -> 3019       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3020       seen_names = set()
#    3021       captured = object_identity.ObjectIdentitySet(
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3194     arg_names = base_arg_names + missing_arg_names
#    3195     graph_function = ConcreteFunction(
# -> 3196         func_graph_module.func_graph_from_py_func(
#    3197             self._name,
#    3198             self._python_function,
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in wrapper_fn(*args)
#    3517       def wrapper_fn(*args):  # pylint: disable=missing-docstring
#    3518         ret = _wrapper_helper(*args)
# -> 3519         ret = structure.to_tensor_list(self._output_structure, ret)
#    3520         return [ops.convert_to_tensor(t) for t in ret]
#    3521
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py in to_tensor_list(element_spec, element)
#     387   # pylint: disable=protected-access
#     388   # pylint: disable=g-long-lambda
# --> 389   return _to_tensor_list_helper(
#     390       lambda state, spec, component: state + spec._to_tensor_list(component),
#     391       element_spec, element)
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py in _to_tensor_list_helper(encode_fn, element_spec, element)
#     337     return encode_fn(state, spec, component)
#     338
# --> 339   return functools.reduce(
#     340       reduce_fn, zip(nest.flatten(element_spec), nest.flatten(element)), [])
#     341
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py in reduce_fn(state, value)
#     335   def reduce_fn(state, value):
#     336     spec, component = value
# --> 337     return encode_fn(state, spec, component)
#     338
#     339   return functools.reduce(
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py in <lambda>(state, spec, component)
#     388   # pylint: disable=g-long-lambda
#     389   return _to_tensor_list_helper(
# --> 390       lambda state, spec, component: state + spec._to_tensor_list(component),
#     391       element_spec, element)
#     392
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/framework/type_spec.py in _to_tensor_list(self, value)
#     227       can be used to reconstruct `value`.
#     228     """
# --> 229     return nest.flatten(self._to_components(value), expand_composites=True)
#     230
#     231   def _from_tensor_list(self, tensor_list):
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/framework/tensor_spec.py in _to_components(self, value)
#     159       raise ValueError("Value %r is not convertible to a tensor with dtype %s "
#     160                        "and shape %s." % (value, self._dtype, self._shape))
# --> 161     if not value.shape.is_compatible_with(self._shape):
#     162       raise ValueError("Value %r is not convertible to a tensor with dtype %s "
#     163                        "and shape %s." % (value, self._dtype, self._shape))
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/framework/tensor_shape.py in is_compatible_with(self, other)
#    1115         return False
#    1116       for x_dim, y_dim in zip(self._dims, other.dims):
# -> 1117         if not x_dim.is_compatible_with(y_dim):
#    1118           return False
#    1119     return True
#
# ~/Library/Caches/pypoetry/virtualenvs/name-transliteration-sfy7S-9L-py3.8/lib/python3.8/site-packages/tensorflow/python/framework/tensor_shape.py in is_compatible_with(self, other)
#     265     """
#     266     other = as_dimension(other)
# --> 267     return (self._value is None or other.value is None or
#     268             self._value == other.value)
#     269
#
# KeyboardInterrupt:

# %%
my_filter2.getDataFrame()
# Out:
#               username         screen_name language
# 0              mi_ano_                   ゆ       ja
# 1              bede908            在りし日のビート       ja
# 2       ShiN_Lionhart2      ｼﾝこれでも実況者放送日未定       ja
# 3         shinzan_yaro  職人系ゲーマーしんさんみんなの配偶者       ja
# 4            yuuuuka08           優華おおきくなぁれ       ja
# ...                ...                 ...      ...
# 51658           s2i1r2                  さー       ja
# 51659     jimoto__love           やっぱり地元が一番       ja
# 51660  erusyadaiLucife               ルシフェル       ja
# 51661     japan_lawson      ローソン公式返信用アカウント       ja
# 51662       susususmum             スススフライト       ja
#
# [51663 rows x 3 columns]

# %%
probability_list
# Out:
# [0.9999958,
#  0.9998889,
#  0.9892664,
#  0.9017037,
#  0.45914155,
#  0.9998821,
#  0.98082525,
#  0.9967796,
#  0.7935591,
#  0.9985879,
#  0.7883587,
#  0.6823935,
#  0.89823395,
#  0.9703076,
#  0.9984864,
#  0.9998609,
#  0.99928963,
#  0.9849045,
#  0.97660214,
#  0.78389764,
#  0.9991955,
#  0.46487087,
#  0.84513426,
#  0.9957283,
#  0.94750154,
#  0.9999976,
#  0.11456417,
#  0.9998779,
#  0.9838855,
#  0.9352533,
#  0.9797563,
#  0.3183916,
#  0.95756245,
#  0.99958235,
#  0.99287534,
#  0.99999857,
#  0.5092954,
#  0.97196645,
#  0.98719877,
#  0.99999535,
#  0.44574982,
#  0.83502835,
#  0.8861339,
#  0.9999311,
#  1.0,
#  0.9872479,
#  0.99831367,
#  0.9999255,
#  0.99999964,
#  0.7353923,
#  0.9999851,
#  0.9981346,
#  0.8611401,
#  0.9999988,
#  0.99890137,
#  0.99807584,
#  0.99986696,
#  0.9971277,
#  0.9994116,
#  0.8164018,
#  0.99996996,
#  0.675875,
#  0.9923781,
#  0.9973028,
#  0.06197386,
#  0.8627356,
#  0.99167717,
#  0.9981343,
#  0.99880755,
#  0.9979013,
#  0.40939674,
#  0.25753796,
#  0.9745238,
#  0.15866017,
#  0.402665,
#  0.57305837,
#  0.2769329,
#  0.94444686,
#  0.9996867,
#  0.9988305,
#  0.9961934,
#  0.9986754,
#  0.9999745,
#  0.99213964,
#  0.99384683,
#  0.99937785,
#  0.99754936,
#  0.9701128,
#  0.4510726,
#  0.9983719,
#  0.63093907,
#  0.9923578,
#  0.6360739,
#  0.8390504,
#  0.999995,
#  0.89208245,
#  0.9999914,
#  0.84200555,
#  0.99323326,
#  0.995567,
#  0.99999774,
#  0.9557809,
#  0.9999896,
#  0.99997735,
#  0.9878051,
#  0.9999918,
#  0.99323046,
#  0.9698247,
#  0.9992085,
#  0.88273495,
#  0.99980277,
#  0.123571254,
#  0.6123529,
#  0.59904706,
#  0.6366465,
#  0.9983944,
#  0.56909895,
#  0.36635816,
#  0.9967609,
#  0.9849316,
#  0.55938727,
#  0.9877814,
#  0.75531036,
#  0.6549293,
#  0.59294313,
#  0.91108716,
#  0.9979518,
#  0.9999752,
#  0.17915075,
#  0.28398016,
#  0.9435579,
#  0.99999547,
#  0.98795855,
#  0.24987507,
#  0.9999994,
#  0.9998647,
#  0.9013106,
#  0.99465925,
#  0.5621781,
#  0.9943165,
#  0.98641497,
#  0.9611855,
#  0.9409213,
#  0.9988714,
#  0.99997175,
#  0.57055795,
#  0.99884087,
#  0.99834406,
#  0.9999243,
#  0.88895595,
#  0.47238418,
#  0.9966978,
#  0.99911433,
#  0.22963473,
#  0.66105306,
#  0.7454642,
#  0.8496978,
#  0.96381474,
#  0.8978895,
#  0.963213,
#  0.9995628,
#  0.9879951,
#  0.9998585,
#  0.9907135,
#  0.9616326,
#  0.9608515,
#  0.99874204,
#  0.9691066,
#  0.98731226,
#  0.28409293,
#  0.9984445,
#  0.99582565,
#  0.6851736,
#  0.91889095,
#  0.99891734,
#  0.25324616,
#  0.99408543,
#  0.99998426,
#  0.9999893,
#  0.9798164,
#  0.20000446,
#  0.9999944,
#  0.3328214,
#  0.97874886,
#  0.38096768,
#  0.9773615]

# %%
trainer_and_tester.max_encoder_seq_length
# Out:
# 17
