# %% [markdown]
# # Cleansing
#
# This note book will be dedicated to cleansing the Twitter data using IPA
#
# This is part of the cleansing stage described in the Design Document.
#
# ## input:
#     - filtered Twitter user name data in the form of csv
# ## output:
#     - a csv file with similar user name and screen name
#
#     - hopefully a good dataset to train on

# %%
# !pip install epitran
# !pip install eng-to-ipa
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Collecting epitran
#   Using cached epitran-1.9-py2.py3-none-any.whl (137 kB)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages (from epitran) (41.2.0)
# Collecting regex
#   Downloading regex-2021.4.4.tar.gz (693 kB)
#      |████████████████████████████████| 693 kB 2.4 MB/s eta 0:00:01
# Collecting unicodecsv
#   Using cached unicodecsv-0.14.1.tar.gz (10 kB)
# Collecting panphon>=0.16
#   Using cached panphon-0.17-py2.py3-none-any.whl (71 kB)
# Collecting marisa-trie
#   Using cached marisa-trie-0.7.5.tar.gz (270 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Frameworks/Python.framework/Versions/2.7/Resources/Python.app/Contents/MacOS/Python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/pip-install-dNAMBB/marisa-trie/setup.py'"'"'; __file__='"'"'/private/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/pip-install-dNAMBB/marisa-trie/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/pip-pip-egg-info-zbfgvs
#          cwd: /private/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/pip-install-dNAMBB/marisa-trie/
#     Complete output (106 lines):
#     /var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/easy_install-7OFrl6/pytest-runner-5.3.0/temp/easy_install-oRj19O/setuptools_scm-6.0.1/src
#     <pkg_resources.WorkingSet object at 0x7fc5db7761d0>
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/pip-install-dNAMBB/marisa-trie/setup.py", line 77, in <module>
#         tests_require=["pytest", "hypothesis==2.0.0"])
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/__init__.py", line 144, in setup
#         _install_setup_requires(attrs)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/__init__.py", line 139, in _install_setup_requires
#         dist.fetch_build_eggs(dist.setup_requires)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/dist.py", line 719, in fetch_build_eggs
#         replace_conflicting=True,
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pkg_resources/__init__.py", line 782, in resolve
#         replace_conflicting=replace_conflicting
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pkg_resources/__init__.py", line 1065, in best_match
#         return self.obtain(req, installer)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pkg_resources/__init__.py", line 1077, in obtain
#         return installer(requirement)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/dist.py", line 786, in fetch_build_egg
#         return cmd.easy_install(req)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/command/easy_install.py", line 679, in easy_install
#         return self.install_item(spec, dist.location, tmpdir, deps)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/command/easy_install.py", line 705, in install_item
#         dists = self.install_eggs(spec, download, tmpdir)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/command/easy_install.py", line 890, in install_eggs
#         return self.build_and_install(setup_script, setup_base)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/command/easy_install.py", line 1158, in build_and_install
#         self.run_setup(setup_script, setup_base, args)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/command/easy_install.py", line 1144, in run_setup
#         run_setup(setup_script, args)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 253, in run_setup
#         raise
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/contextlib.py", line 35, in __exit__
#         self.gen.throw(type, value, traceback)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 195, in setup_context
#         yield
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/contextlib.py", line 35, in __exit__
#         self.gen.throw(type, value, traceback)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 166, in save_modules
#         saved_exc.resume()
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 141, in resume
#         six.reraise(type, exc, self._tb)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 154, in save_modules
#         yield saved
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 195, in setup_context
#         yield
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 250, in run_setup
#         _execfile(setup_script, ns)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 45, in _execfile
#         exec(code, globals, locals)
#       File "/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/easy_install-7OFrl6/pytest-runner-5.3.0/setup.py", line 21, in <module>
#         MARISA_FILES[:] = itertools.chain(
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/__init__.py", line 144, in setup
#         _install_setup_requires(attrs)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/__init__.py", line 139, in _install_setup_requires
#         dist.fetch_build_eggs(dist.setup_requires)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/dist.py", line 719, in fetch_build_eggs
#         replace_conflicting=True,
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pkg_resources/__init__.py", line 782, in resolve
#         replace_conflicting=replace_conflicting
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pkg_resources/__init__.py", line 1065, in best_match
#         return self.obtain(req, installer)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pkg_resources/__init__.py", line 1077, in obtain
#         return installer(requirement)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/dist.py", line 786, in fetch_build_egg
#         return cmd.easy_install(req)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/command/easy_install.py", line 679, in easy_install
#         return self.install_item(spec, dist.location, tmpdir, deps)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/command/easy_install.py", line 705, in install_item
#         dists = self.install_eggs(spec, download, tmpdir)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/command/easy_install.py", line 890, in install_eggs
#         return self.build_and_install(setup_script, setup_base)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/command/easy_install.py", line 1158, in build_and_install
#         self.run_setup(setup_script, setup_base, args)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/command/easy_install.py", line 1144, in run_setup
#         run_setup(setup_script, args)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 253, in run_setup
#         raise
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/contextlib.py", line 35, in __exit__
#         self.gen.throw(type, value, traceback)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 195, in setup_context
#         yield
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/contextlib.py", line 35, in __exit__
#         self.gen.throw(type, value, traceback)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 166, in save_modules
#         saved_exc.resume()
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 141, in resume
#         six.reraise(type, exc, self._tb)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 154, in save_modules
#         yield saved
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 195, in setup_context
#         yield
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 250, in run_setup
#         _execfile(setup_script, ns)
#       File "/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/setuptools/sandbox.py", line 45, in _execfile
#         exec(code, globals, locals)
#       File "/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/easy_install-7OFrl6/pytest-runner-5.3.0/temp/easy_install-oRj19O/setuptools_scm-6.0.1/setup.py", line 52, in <module>
#         author="Mikhail Korobov",
#       File "/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/easy_install-7OFrl6/pytest-runner-5.3.0/temp/easy_install-oRj19O/setuptools_scm-6.0.1/setup.py", line 29, in scm_config
#         CLASSIFIERS = [
#       File "/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/easy_install-7OFrl6/pytest-runner-5.3.0/temp/easy_install-oRj19O/setuptools_scm-6.0.1/src/setuptools_scm/__init__.py", line 8, in <module>
#       File "/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/easy_install-7OFrl6/pytest-runner-5.3.0/temp/easy_install-oRj19O/setuptools_scm-6.0.1/src/setuptools_scm/config.py", line 6, in <module>
#       File "/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/easy_install-7OFrl6/pytest-runner-5.3.0/temp/easy_install-oRj19O/setuptools_scm-6.0.1/src/setuptools_scm/utils.py", line 41
#         print(*k)
#               ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# WARNING: You are using pip version 20.1.1; however, version 20.3.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/2.7/Resources/Python.app/Contents/MacOS/Python -m pip install --upgrade pip' command.
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Collecting eng-to-ipa
#   Using cached eng_to_ipa-0.0.2.tar.gz (2.8 MB)
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Frameworks/Python.framework/Versions/2.7/Resources/Python.app/Contents/MacOS/Python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/pip-install-pS4XPi/eng-to-ipa/setup.py'"'"'; __file__='"'"'/private/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/pip-install-pS4XPi/eng-to-ipa/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/pip-pip-egg-info-Obztrg
#          cwd: /private/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/pip-install-pS4XPi/eng-to-ipa/
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/tl/f8n8jtxs6vg0j4kd0wjfv3_00000gn/T/pip-install-pS4XPi/eng-to-ipa/setup.py", line 3, in <module>
#         with open("README.md", 'r', encoding='utf-8') as f:
#     TypeError: 'encoding' is an invalid keyword argument for this function
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# WARNING: You are using pip version 20.1.1; however, version 20.3.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/2.7/Resources/Python.app/Contents/MacOS/Python -m pip install --upgrade pip' command.

# %%
# !pip3 install editdistance
# Out:
# Requirement already satisfied: editdistance in /usr/local/lib/python3.9/site-packages (0.5.3)

# %%
import eng-to-ipa
# Out:
#   File "<ipython-input-10-3e7acfc33b17>", line 1
#     import eng-to-ipa
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
ja_data = pd.read_csv('ja_data.csv')
ja_data.dropna(inplace=True)
ja_data.reset_index(drop=True, inplace=True)

ja_data.head()
# Out:
#                username      screen_name
# 0                 もるなかー     MelanchoLuna
# 1  ₦Ø₱₱Ø₲ł🦒APEX Valheim        nopogi114
# 2                   Rio      rrrrrrinrun
# 3                ポテチのり塩   pote_nori_game
# 4            ジェイドドーベルマン  KvsooxBXnGVTe95

# %%
import pykakasi
import editdistance

edit_threshold = 4
rows_over_threshold = []
ja_data_small = ja_data.iloc[:3000]
for index, row in ja_data_small.iterrows():
    username = row.username
    screen_name = row.screen_name
    kks = pykakasi.kakasi()
    translit = kks.convert(username)
    roman = ''
    for item in translit:
        roman = roman + item['hepburn']
    edit_distance = editdistance.eval(roman, screen_name)
    if edit_distance > edit_threshold:
        rows_over_threshold.append(index)

# %%
ja_data_small.drop(rows_over_threshold)
# Out:
#              username      screen_name
# 15           sawadama        sawadama_
# 16          WEttonton        EttontonW
# 38        Final stage     Finalstage11
# 56            sono106          sono106
# 58                 モモ         moy_om_o
# 61           Макарова      Hg_Makarova
# 65               メイたん          mei6242
# 67              まちゃおじ        macha_oji
# 74         Alice&Mona       AliceMona5
# 76                うぬこ             unuk
# 88              みーぼん🦄        miibon671
# 94               ぱんぞう       panzou0625
# 102               わをん           _wawon
# 110               ぽき❕         poki_mns
# 115               こてつ         kote9999
# 126               まつ子       matsuko_23
# 137              もっこす         mokkosu6
# 182              くろろん           ku66on
# 199          kiraxiii        kiraxiii1
# 203               タロゥ          00_taro
# 241              ぱないの      panaino1021
# 244         breaker75        breaker75
# 258               yun           yuneb4
# 264   economicscience  economicscience
# 266           komachi          komi_o0
# 270                燐汰          pi_utan
# 275            motoju          motoju_
# 276            マーキーさん        markeesan
# 300               ゼクス        zekusu8mk
# 301           キャサリンch      kyasarin007
# ...               ...              ...
# 2784             つなぎす        tsuna719g
# 2793               永禄       0846eiroku
# 2794            しまえなが    shima_enaga21
# 2799            きみしぐれ        Kmishigre
# 2801       erica ward       ericaeward
# 2815             まあくん        mahkun_54
# 2820             みなぽり     minaporipori
# 2827              やたま         YaTTaMma
# 2834       miffy_1219       miffy_1219
# 2843         kazutomi         kazutomi
# 2849              きょろ         kyoro_qx
# 2855             ししゃも      shisyamo912
# 2864         momosama        momosama7
# 2868              トワコ         towakooo
# 2878              かーず           Kaa_Zu
# 2889          とあるゲーマー        toarugema
# 2907              あいう          aiu8216
# 2918                春         0426haru
# 2919       crysisjake       crysisjake
# 2922          antirns          antirns
# 2936           skikym       skikym1215
# 2939           oritaw           oritaw
# 2941           rekuto          rekuto6
# 2946             さぶりな       saburinaDA
# 2955            オヤジ生活    oyajiseikatsu
# 2959         よだきんぼ‍❄️    yodakinbo1219
# 2968              いちこ         ichi0619
# 2979             はやかわ     hayakawa_twr
# 2981      ghostlyrain     ghostlyrain1
# 2984  takumi_fukagawa   TakumiFukagawa
#
# [333 rows x 2 columns]

# %%
# Out:
#          username screen_name
# count       54807       54807
# unique      47381       51441
# top     Tポイント【公式】      tpoint
# freq           69          69
